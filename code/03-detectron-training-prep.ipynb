# %%
import cv2
import os
import shutil
from numpy import random
from random import shuffle
from utils.video_scraping import get_savant_video_urls, download_mp4_from_savant

# %% [markdown]
# # Detectron Training Preparation
# ## Background
# Here we randomly download 600 images from 6 pitchers (100 images per pitcher) and use labelImg to annotate the images. The annotated images are then used to train a Detectron2 model on Google Colab.
#
# ## Download Videos
# Download 10 random videos per player

# %%
def download_videos(player_id, season, runners_on_base, dest_path, random_sample, n_sample=10):
    
    # Get player videos for full season
    print(f"Player ID: {player_id}")
    video_urls = get_savant_video_urls(player_id=player_id, season=season, runners_on_base=runners_on_base)
    print(f"{len(video_urls)} videos available for this season...")
    
    # Select random sample of videos if random_sample parameter is set to true
    if random_sample:
        video_urls = random.sample(video_urls, n_sample)
        print(f"But sampling {n_sample} videos...")
        
    # Download videos
    for video_url in video_urls:
        try:
            download_mp4_from_savant(savant_url=video_url, path=dest_path)
        except:
            continue
    
    # New line
    print("")

# %%
player_info = {
    "Clayton Kershaw": {"player_id": "477132", "season": 2019}, 
    "Walker Buehler": {"player_id": "621111", "season": 2021}, 
    "Tony Gonsolin": {"player_id": "664062", "season": 2022}, 
    "Tyler Anderson": {"player_id": "542881", "season": 2022}, 
    "Mitch White": {"player_id": "669952", "season": 2022}, 
    # Note: Tyler Glasnow always pitches from the stretch
    "Tyler Glasnow": {"player_id": "607192", "season": 2019}}

for player in list(player_info.keys()):
    player_id = player_info[player]["player_id"]
    season = player_info[player]["season"]
    print(f"Getting videos for {player}'s {season} season")
    download_videos(player_id, season, runners_on_base=True, dest_path="../data/detectron-training/videos", random_sample=True)

# %% [markdown]
# ## Convert Videos to Images
# Generating 10 images randomly from each video, which equates to 100 random images per pitcher and 600 random images total. These images will be annotated and used to train a Detectron 2 pitcher detector model.

# %%
def mp4_to_image(input_dir, output_dir, n_frames=10):

    # Get list of files to extract images from
    mp4s = [f"{input_dir}/{file}" for file in os.listdir(input_dir) if ".mp4" in file]
    
    # Output 10 random jpgs per video
    for i, mp4 in enumerate(mp4s, 1):
        
        # Message
        print(f"\nVideo {i}")

        # Get random n frames from each video
        random.seed(seed=0)
        vidcap = cv2.VideoCapture(mp4)
        totalFrames = vidcap.get(cv2.CAP_PROP_FRAME_COUNT)
        randomFrames = random.randint(totalFrames, size=(n_frames))

        # Output each frame as jpg
        for i, randomFrameNumber in enumerate(randomFrames, 1):
            
            # Message
            print(f"Outputting image {i}/{n_frames}...")
            
            # Set video to specified frame number
            vidcap.set(cv2.CAP_PROP_POS_FRAMES, randomFrameNumber)
            success, image = vidcap.read()
            if success:
                output_file = f"{output_dir}/{mp4.split('/')[-1].split('.mp4')[0]}-{i}.jpg"
                cv2.imwrite(output_file, image)

#mp4_to_image(input_dir="../data/detectron-training/videos", output_dir="../data/detectron-training/images")

# %% [markdown]
# ## Annotate Images with LabelImg
# Annotating images with labelimg (https://github.com/heartexlabs/labelImg). Once installed, calling 'labelImg' from the command line opens up an interface to annotate images (in this case labeling the pitcher in a given frame). I originally saved annotations as yolo txt files. These may need to be converted to xml files and then to a coco json file.

# %%
#!pip3 install labelImg

# %% [markdown]
# ## Converting Annotation File Types
# txt --> xml --> coco
#
# ### txt --> xml
# The script used here is the txt_to_xml.py file from https://github.com/sowmyakavali/Data-convertion.git. I found some bugs in the script that needed to be fixed. The edits that were made were saved in a new file called txt_to_xml-2.py. The original file is preserved and can be referenced.

# %%
#!git clone https://github.com/sowmyakavali/Data-convertion.git
# Out:
# Cloning into 'Data-convertion'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 4), reused 1 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 11.14 KiB | 11.14 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# Move Data-convertion directory
#shutil.move('./Data-convertion', '../data/detectron-training/helper_packages/Data-convertion')

# %%
#!python ../data/detectron-training/helper_packages/Data-convertion/txt_to_xml-2.py -i ../data/detectron-training/annotations_txt/ -img ../data/detectron-training/images/ -o ../data/detectron-training/annotations_xml/
# Out:
# c1db6892-b2c4-4706-8b08-45eeede02543-5.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-1.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-6.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-7.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-2.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-8.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-2.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-6.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-10.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-2.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-7.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-3.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-3.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-1.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-8.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-8.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-6.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-2.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-3.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-7.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-6.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-2.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-3.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-7.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-9.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-9.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-2.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-2.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-6.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-10.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-3.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-7.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-3.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-9.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-3.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-6.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-10.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-7.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-10.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-10.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-4.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-2.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-6.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-5.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-4.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-9.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-1.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-8.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-1.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-5.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-4.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-1.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-9.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-2.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-8.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-5.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-1.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-9.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-4.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-10.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-1.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-8.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-5.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-4.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-9.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-1.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-8.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-3.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-1.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-10.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-5.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-4.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-9.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-8.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-5.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-4.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-7.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-3.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-7.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-3.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-1.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-4.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-4.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-1.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-10.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-10.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-4.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-10.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-5.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-7.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-5.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-1.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-9.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-9.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-5.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-4.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-8.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-9.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-5.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-8.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-4.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-8.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-1.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-4.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-6.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-4.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-5.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-5.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-1.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-5.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-2.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-6.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-1.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-3.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-4.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-10.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-2.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-7.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-10.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-8.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-3.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-10.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-7.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-8.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-7.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-2.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-6.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-6.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-4.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-8.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-3.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-6.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-2.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-10.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-7.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-6.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-3.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-7.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-2.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-10.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-9.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-5.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-7.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-7.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-3.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-6.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-9.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-6.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-2.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-9.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-6.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-3.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-5.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-1.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-2.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-9.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-9.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-3.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-8.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-3.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-7.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-10.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-9.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-6.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-8.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-4.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-5.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-9.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-4.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-10.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-5.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-8.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-10.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-4.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-5.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-9.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-1.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-1.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-1.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-1.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-8.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-7.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-10.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-6.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-2.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-9.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-2.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-10.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-8.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-8.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-10.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-9.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-4.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-9.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-5.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-3.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-3.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-3.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-9.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-3.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-7.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-8.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-7.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-6.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-7.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-6.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-9.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-6.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-2.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-8.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-2.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-2.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-4.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-2.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-10.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-8.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-5.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-1.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-1.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-8.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-10.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-9.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-1.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-5.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-5.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-8.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-9.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-8.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-9.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-6.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-6.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-10.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-6.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-6.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-2.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-2.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-3.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-2.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-3.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-3.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-10.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-7.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-7.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-1.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-7.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-7.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-9.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-8.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-8.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-10.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-9.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-4.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-4.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-8.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-9.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-9.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-2.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-6.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-6.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-8.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-8.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-5.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-5.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-3.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-5.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-5.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-1.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-10.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-1.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-1.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-4.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-2.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-4.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-4.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-4.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-9.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-9.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-7.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-10.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-10.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-7.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-3.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-10.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-8.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-8.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-5.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-3.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-5.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-10.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-10.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-6.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-1.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-7.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-3.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-4.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-6.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-4.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-6.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-7.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-9.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-9.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-9.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-1.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-9.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-3.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-2.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-1.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-3.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-2.txt-->start!
# e35f9c43-1c32-488a-8c8f-d3715c3b75b3-8.txt-->start!
# 12a6cc92-c8fe-4e16-9f99-16b697aca1d8-8.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-1.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-8.txt-->start!
# 2c119be3-18d0-4381-961f-7fc4b75d0d78-8.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-10.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-7.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-6.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-5.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-7.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-5.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-2.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-6.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-7.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-4.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-2.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-1.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-1.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-4.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-3.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-6.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-3.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-6.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-9.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-2.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-5.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-9.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-7.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-4.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-5.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-7.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-4.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-5.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-3.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-10.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-2.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-1.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-3.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-2.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-1.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-3.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-2.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-5.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-4.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-6.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-4.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-10.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-1.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-5.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-6.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-8.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-4.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-3.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-8.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-1.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-7.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-2.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-7.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-2.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-6.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-6.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-3.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-10.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-3.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-5.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-8.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-7.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-2.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-1.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-5.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-2.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-9.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-6.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-10.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-1.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-5.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-7.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-10.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-4.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-6.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-10.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-7.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-5.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-6.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-10.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-4.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-1.txt-->start!
# 1bc10f0b-fd61-4adc-bcdf-0e3626264b61-8.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-10.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-7.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-1.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-3.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-4.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-3.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-1.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-6.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-9.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-4.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-2.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-2.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-7.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-7.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-5.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-5.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-6.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-10.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-3.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-4.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-2.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-6.txt-->start!
# ebdc5532-3b83-44f5-bb53-ab7b579b138c-1.txt-->start!
# d7f29851-0c17-4e92-a409-8eaab9ebbfa5-1.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-10.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-3.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-10.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-5.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-2.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-3.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-6.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-4.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-7.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-5.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-8.txt-->start!
# 788ce2fd-9217-447c-aa4f-3861126c97dc-10.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-8.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-10.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-9.txt-->start!
# 0b6c74c9-1dd3-4b1a-836a-40dab6a485c0-8.txt-->start!
# 325be744-5f64-4eb4-b471-2956baf21ca2-9.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-9.txt-->start!
# f8a22549-1aba-438f-a2dd-435000c1c806-4.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-6.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-5.txt-->start!
# 41f5139d-96a4-4574-a531-fd4fdb49811f-7.txt-->start!
# 1ee0ed64-7c0b-46ac-8f4c-8e845bb6ac45-3.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-2.txt-->start!
# 0653d294-b000-4fce-a321-702cb92fad9b-4.txt-->start!
# 1f0395db-82d0-4584-839e-c3d8f5b3164d-2.txt-->start!
# b4eaeca5-a2f0-49da-b7ea-0960ae4f8f0f-10.txt-->start!
# dffb5a04-88b0-4dfc-ada7-ed80b334e2bf-7.txt-->start!
# 1199091a-eb82-4a1a-a5a9-bc82e218fd1a-3.txt-->start!
# 131789d8-85cd-47d9-8cbd-44af657b4863-5.txt-->start!
# 3a63bc20-d0ce-499f-8253-50e5be82789b-2.txt-->start!
# a9534d93-6001-4f8b-9a38-50150a5cf4ef-10.txt-->start!
# e592d7d9-9b7f-465a-88de-49690976e52a-1.txt-->start!
# cc36b9a2-9f60-415b-a84b-62a0ee003a39-7.txt-->start!
# 29bd0a4e-d144-42f3-9f3d-e60207c39777-4.txt-->start!
# 0a4b7d48-3ab6-435f-bbd7-7716f114a062-1.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-4.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-8.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-3.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-2.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-4.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-1.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-4.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-2.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-1.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-3.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-8.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-1.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-4.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-10.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-3.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-6.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-6.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-7.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-6.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-7.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-7.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-2.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-5.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-2.txt-->start!
# d052f91e-dc06-480d-8b91-c2c0ee2a8e80-10.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-9.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-3.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-10.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-5.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-5.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-3.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-2.txt-->start!
# 6136fe4f-e136-4ba1-bbc0-ef5308d6e592-9.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-8.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-1.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-2.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-7.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-8.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-7.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-8.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-2.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-1.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-9.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-9.txt-->start!
# d6756d26-7ee5-4f74-98d6-dd8c9d142e6c-10.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-7.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-2.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-5.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-9.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-5.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-4.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-8.txt-->start!
# b320529f-842e-4b27-94c2-833461c4475e-9.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-5.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-4.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-1.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-4.txt-->start!
# 66919ef7-0420-42dd-8e08-d2193e078968-8.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-3.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-6.txt-->start!
# 5ec4a912-b95f-4c13-a963-b7d7cf7859bd-8.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-1.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-8.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-3.txt-->start!
# 2712fdd9-98a3-4ac0-8c90-f94b93caa264-9.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-6.txt-->start!
# ce1ab1e6-1b54-4730-84d3-deabfd90d25a-9.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-6.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-10.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-3.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-1.txt-->start!
# 14e67b7b-aea2-445f-872e-f69ca0197b2f-9.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-9.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-5.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-8.txt-->start!
# dae02688-1cdc-41ac-838d-73240bff93b7-10.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-7.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-2.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-4.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-2.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-9.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-8.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-5.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-4.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-7.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-2.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-9.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-7.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-1.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-5.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-8.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-1.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-4.txt-->start!
# 29a7131e-7823-495c-9275-731f6423a525-9.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-1.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-6.txt-->start!
# 3ea6a4c1-9962-401e-a90c-95ba49d4f45a-8.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-3.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-5.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-6.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-4.txt-->start!
# 3d9e316c-9cc5-49e3-93c4-ac8d662d300b-9.txt-->start!
# 7fa54d27-4e39-47ca-88ee-5be698a9f294-10.txt-->start!
# 4e1c34af-4fba-4c0a-b38b-6748e694b496-10.txt-->start!
# ecc21930-dc56-4677-9475-8408a1230702-8.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-3.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-5.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-3.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-6.txt-->start!
# 2c3e4ffe-1b80-4d1b-907b-acaba78875cb-9.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-4.txt-->start!
# 1a9aad4c-88eb-4133-8ad1-fd41b702b2d7-8.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-9.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-6.txt-->start!
# a0dcc4bf-8b91-4057-ac96-d8bfdaf43f00-1.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-4.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-7.txt-->start!
# 01c315f9-dcb3-40ed-ada5-b4975fff06f7-1.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-6.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-4.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-7.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-4.txt-->start!
# bf4b48ef-0ad6-43da-9190-00a67b9b966a-1.txt-->start!
# 924a02b7-f10b-4554-bd74-b8a618c50562-10.txt-->start!
# be9961a3-6208-4d02-81c4-9beeb8fdff42-10.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-2.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-6.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-3.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-3.txt-->start!
# d1b08ac1-551c-46fb-9d66-69b051233136-2.txt-->start!
# 782b5c61-0dca-46ba-b85f-7927d2a68229-2.txt-->start!
# 00f5c72b-cece-4127-9d80-046a01104466-7.txt-->start!
# 016ad612-fec1-4e1a-8303-8bf2052c9b22-3.txt-->start!
# 66bfb6b6-f36a-4ae8-b182-4fd410153678-5.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-10.txt-->start!
# d45e0c51-5f72-4d92-abfa-f6cec08d4918-5.txt-->start!
# c35f1d47-3f4d-4586-86b7-4daf4208721e-6.txt-->start!
# fde6e27c-dfa7-4712-8a76-dc2bb0c64998-7.txt-->start!
# b789775b-1b5c-40e1-b09c-04f8d67f99de-10.txt-->start!
# c9e807cb-2d9b-44c2-a23e-01d182488763-6.txt-->start!
# be3c2e55-7a4a-44cd-9473-ab81f576193e-5.txt-->start!
# de771fdc-f462-4900-a535-e86b4ea41df8-7.txt-->start!
# c1db6892-b2c4-4706-8b08-45eeede02543-8.txt-->start!

# %% [markdown]
# ### Split into Training and Validation Sets

# %%
# Randomize xml files
xml_files = [file for file in os.listdir('data/detectron-training/annotations_xml') if ".xml" in file]
random.seed(0)
random.shuffle(xml_files)

if xml_files:

    # Partition into training and validation sets
    xml_train = xml_files[:500]
    xml_val = xml_files[500:]

    # Make new paths to store training and validation data
    if not os.path.exists('data/detectron-training/annotations_xml/training'):
        os.mkdir('data/detectron-training/annotations_xml/training')

    if not os.path.exists('data/detectron-training/annotations_xml/validation'):
        os.mkdir('data/detectron-training/annotations_xml/validation')

    # Move files to new destinations
    # Training data
    for file in xml_train:
        source_folder = 'data/detectron-training/annotations_xml'
        destination_folder = 'data/detectron-training/annotations_xml/training'
        shutil.move(f'{source_folder}/{file}', f'{destination_folder}/{file}')

    # Validation data
    for file in xml_val:
        source_folder = 'data/detectron-training/annotations_xml'
        destination_folder = 'data/detectron-training/annotations_xml/validation'
        shutil.move(f'{source_folder}/{file}', f'{destination_folder}/{file}')

# %%
# Now doing this to images
img_train = [f'{file.split(".xml")[0]}.jpg' for file in xml_train]
img_val = [f'{file.split(".xml")[0]}.jpg' for file in xml_val]

# Make new paths to store training and validation data
if not os.path.exists('data/detectron-training/images/training'):
    os.mkdir('data/detectron-training/images/training')

if not os.path.exists('data/detectron-training/images/validation'):
    os.mkdir('data/detectron-training/images/validation')

# Move files to new destinations
# Training data
for file in img_train:
    source_folder = 'data/detectron-training/images'
    destination_folder = 'data/detectron-training/images/training'
    shutil.move(f'{source_folder}/{file}', f'{destination_folder}/{file}')

# Validation data
for file in img_val:
    source_folder = 'data/detectron-training/images'
    destination_folder = 'data/detectron-training/images/validation'
    shutil.move(f'{source_folder}/{file}', f'{destination_folder}/{file}')

# %% [markdown]
# ### xml --> coco
# The script used here is the vooc2coco.py file from https://github.com/Tony607/voc2coco.git. There was a weird requirement to have images titled as numbers so I made a slight edit to the script. The changes were saved in voc2coco/voc2coco-2.py, which is used below.

# %%
#!git clone https://github.com/Tony607/voc2coco.git
# Out:
# Cloning into 'voc2coco'...
# remote: Enumerating objects: 50, done.
# remote: Total 50 (delta 0), reused 0 (delta 0), pack-reused 50
# Receiving objects: 100% (50/50), 4.37 MiB | 5.30 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# Move voc2coco directory
#shutil.move('./voc2coco', '../data/detectron-training/helper_packages/voc2coco')

# %%
#!python ../data/detectron-training/helper_packages/voc2coco/voc2coco-2.py ../data/detectron-training/annotations_xml/training/ ../data/detectron-training/annotations_coco/training/pitcher_annotations.json
# Out:
# Number of xml files: 500
# Success: ./data/detectron-training/annotations_coco/training/pitcher_annotations.json

# %%
#!python ../data/detectron-training/helper_packages/voc2coco/voc2coco-2.py ../data/detectron-training/annotations_xml/validation/ ../data/detectron-training/annotations_coco/validation/pitcher_annotations.json
# Out:
# Number of xml files: 100
# Success: ./data/detectron-training/annotations_coco/validation/pitcher_annotations.json

# %% [markdown]
# ## Detectron Training
# Detectron training was performed in a Google Colab notebook to make use of a GPU. The notebook can be found at https://colab.research.google.com/drive/1bl9DoAHkTPCcU2vy4WM4vkuqxFLBp2n_?authuser=1#scrollTo=xvemhFnpFI1x.
